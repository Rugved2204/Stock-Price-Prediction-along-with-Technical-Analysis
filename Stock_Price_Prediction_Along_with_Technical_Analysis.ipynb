# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import date
import math
import pandas_datareader as web
import yfinance as yf #helps to download data from yahoo finance

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
data = yf.download('^NSEBANK', start = datetime.datetime(2000, 1, 2), end = date.today())
data = data[['Adj Close']] #Took only one column
data.columns = ['Price']
data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Price
# Date
# 2007-09-17  6897.020020
# 2007-09-18  7059.567871
# 2007-09-19  7401.764160
# 2007-09-20  7390.063965
# 2007-09-21  7464.413086

# %%
print('There are {} number of days in the dataset.'.format(data.shape[0]))
# Out:
# There are 3850 number of days in the dataset.

# %%
data.index
# Out:
# DatetimeIndex(['2007-09-17', '2007-09-18', '2007-09-19', '2007-09-20',
#                '2007-09-21', '2007-09-24', '2007-09-25', '2007-09-26',
#                '2007-09-27', '2007-09-28',
#                ...
#                '2024-07-02', '2024-07-03', '2024-07-04', '2024-07-05',
#                '2024-07-08', '2024-07-09', '2024-07-10', '2024-07-11',
#                '2024-07-12', '2024-07-15'],
#               dtype='datetime64[ns]', name='Date', length=3850, freq=None)

# %%
plt.figure(figsize=(28, 12))#, dpi=100)
plt.plot(data.index, data['Price'], label='Bank Nifty Price')
plt.xlabel('Date')
plt.ylabel('Rs')
plt.title('Bank Nifty Price')
plt.legend()
plt.show()

# %%
def get_technical_indicators(data):
  #moving Average
  data['ma7'] = data['Price'].rolling(window=7).mean()
  data['ma21'] = data['Price'].rolling(window=21).mean()
  #MACD Line
  data['ema26'] = data['Price'].ewm(span=26).mean()
  data['ema12'] = data['Price'].ewm(span=12).mean()
  data['MACD'] = data['ema12'] - data['ema26']

  #Exponential Moving Line
  data['ema'] = data['Price'].ewm(com=0.5).mean()
  period = 10
  #Bollinger Band
  data['20sd'] = data['Price'].rolling(window = 21).std()
  data['upper_band'] = data['ma21'] + (data['20sd']*2)
  data['lower_band'] = data['ma21'] - (data['20sd']*2)
  #momentum as an indicator
  data['momentum'] = data['Price'].diff(period)

# Calculate log momentum, taking care to avoid taking log of non-positive values
  data['log_momentum'] = data['momentum'].apply(lambda x: np.log(x) if x > 0 else np.nan)

  return data

# %%
df = get_technical_indicators(data)

# %% [markdown]
# Data Preprocessing

# %%
print(df['log_momentum'])
# Out:
# Date
# 2007-10-16    5.111376
# 2007-10-22    4.971192
# 2007-10-23    6.278697
# 2007-10-24    4.848499
# 2007-10-25    5.298308
#                 ...
# 2024-07-04    2.670640
# 2024-07-09    4.962845
# 2024-07-11    4.398732
# 2024-07-12    2.110213
# 2024-07-15    5.176150
# Name: log_momentum, Length: 2011, dtype: float64

# %%
#Dropping the rows and column having Null values

df = df.dropna()
df.head()
# Out:
#                   Price          ma7         ma21        ema26        ema12  \
# Date
# 2007-10-16  8452.101562  8054.791922  7784.471354  7923.731019  8042.612357
# 2007-10-17  8099.805664  8122.434012  7841.746861  7939.713390  8051.640133
# 2007-10-23  8101.005859  7934.200474  7907.722284  7863.638751  7883.627861
# 2007-10-24  8228.554688  7925.964983  7935.233887  7894.537703  7937.283383
# 2007-10-25  8428.552734  7922.600865  7973.304920  7939.280699  8013.572937
#
#                   MACD          ema        20sd   upper_band   lower_band  \
# Date
# 2007-10-16  118.881339  8363.607803  386.856369  8558.184092  7010.758617
# 2007-10-17  111.926742  8187.739710  334.374992  8510.496844  7172.996878
# 2007-10-23   19.989110  7921.284909  261.172287  8430.066858  7385.377710
# 2007-10-24   42.745680  8126.131428  263.178139  8461.590165  7408.877609
# 2007-10-25   74.292238  8327.745632  274.266189  8521.837299  7424.772542
#
#               momentum  log_momentum
# Date
# 2007-10-16  464.694336      6.141380
# 2007-10-17    2.000000      0.693147
# 2007-10-23  205.247559      5.324217
# 2007-10-24  197.998047      5.288257
# 2007-10-25  269.847656      5.597858

# %%
df.shape  #20 rows with null values removed
# Out:
# (2176, 12)

# %%
def plot_technical_indicators(dataset, last_days):
    plt.figure(figsize=(16, 10), dpi=100)
    shape_0 = dataset.shape[0]
    xmacd_ = shape_0-last_days

    dataset = dataset.iloc[-last_days:, :]
    x_ = range(3, dataset.shape[0])
    x_ =list(dataset.index)

    plt.figure(figsize=(30,20))
    # Plot first subplot
    plt.subplot(2, 1, 1)
    plt.plot(dataset['ma7'],label='MA 7', color='g',linestyle='--')
    plt.plot(dataset['Price'],label='Closing Price', color='b')
    plt.plot(dataset['ma21'],label='MA 21', color='r',linestyle='--')
    plt.plot(dataset['upper_band'],label='Upper Band', color='c')
    plt.plot(dataset['lower_band'],label='Lower Band', color='c')
    plt.fill_between(x_, dataset['lower_band'], dataset['upper_band'], alpha=0.35)
    plt.title('Technical indicators for Goldman Sachs - last {} days.'.format(last_days))
    plt.ylabel('USD')
    plt.legend()

    # Plot second subplot

    plt.subplot(2, 1, 2)
    plt.title('MACD')
    plt.plot(dataset['MACD'],label='MACD', linestyle='-.')
#     plt.hlines(15, xmacd_, shape_0, colors='g', linestyles='--')
#     plt.hlines(-15, xmacd_, shape_0, colors='g', linestyles='--')
    plt.plot(dataset['log_momentum'],label='Momentum', color='b',linestyle='-')

    plt.legend()
    plt.show()

# %%
plot_technical_indicators(df,1000)

# %%
plt.figure(figsize = (28,12))
sns.set_context('poster',font_scale=1)
sns.heatmap(df.corr(), annot = True).set_title('Params')
# Out:
# Text(0.5, 1.0, 'Params')

# %% [markdown]
# This heatmap allows you to quickly identify relationships between different financial indicators. Highly correlated variables can be useful for certain types of analyses and strategies, while weakly or negatively correlated variables might offer diversification benefits in a portfolio. The visualization helps in understanding the structure and relationships in your data, guiding further analysis or decision-making.

# %%
print('Total dataset has {} samples, and {} features.'.format(df.shape[0],df.shape[1]))
# Out:
# Total dataset has 2176 samples, and 12 features.

# %%
df.columns
# Out:
# Index(['Price', 'ma7', 'ma21', 'ema26', 'ema12', 'MACD', 'ema', '20sd',
#        'upper_band', 'lower_band', 'momentum', 'log_momentum'],
#       dtype='object')

# %%
df
# Out:
#                    Price           ma7          ma21         ema26  \
# Date
# 2007-10-16   8452.101562   8054.791922   7784.471354   7923.731019
# 2007-10-17   8099.805664   8122.434012   7841.746861   7939.713390
# 2007-10-23   8101.005859   7934.200474   7907.722284   7863.638751
# 2007-10-24   8228.554688   7925.964983   7935.233887   7894.537703
# 2024-07-03  54188.430839  47693.331065  1691.199219      7.433193
# 2024-07-04  54045.502446  48424.363998  1320.449219      7.185727
# 2024-07-05  54095.700580  48717.570626   998.902344      6.906657
# 2024-07-08  54095.721547  49016.016548   721.851562      6.581820
#
# [769 rows x 12 columns]

# %%
#Scaling the values

scalar = MinMaxScaler()

data_training_scaled = scalar.fit_transform(data_training)
print(data_training_scaled.shape)
data_training_scaled
# Out:
# (1407, 12)
# array([[1.93293896e-01, 1.82402736e-01, 1.67125158e-01, ...,
#         1.57885385e-01, 9.56617788e-02, 7.14916535e-01],
#        [1.78989214e-01, 1.85152871e-01, 1.69484833e-01, ...,
#         1.64555458e-01, 1.44546223e-04, 5.24022039e-02],
#        [1.79037947e-01, 1.77499830e-01, 1.72202932e-01, ...,
#         1.73287035e-01, 4.21023633e-02, 6.15548129e-01],
#        ...,
#        [9.67872348e-01, 9.72188506e-01, 9.68558428e-01, ...,
#         9.68285085e-01, 1.17172152e-01, 7.39517990e-01],
#        [9.64946865e-01, 9.70656909e-01, 9.69111663e-01, ...,
#         9.68518531e-01, 5.37556717e-02, 6.45093876e-01],
#        [9.68069262e-01, 9.70686233e-01, 9.69573079e-01, ...,
#         9.68397567e-01, 4.70150197e-02, 6.28887993e-01]])

# %%
X_train = []
y_train = []

# %%
for i in range(60, data_training.shape[0]):
    X_train.append(data_training_scaled[i-60: i])
    y_train.append(data_training_scaled[i, 0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-e306e0f1ee19> in <cell line: 1>()
#       1 for i in range(60, data_training.shape[0]):
# ----> 2     X_train.append(data_training_scaled[i-60: i])
#       3     y_train.append(data_training_scaled[i, 0])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
data_training_scaled
# Out:
# array([[1.93293896e-01, 1.82402736e-01, 1.67125158e-01, ...,
#         1.57885385e-01, 9.56617788e-02, 7.14916535e-01],
#        [1.78989214e-01, 1.85152871e-01, 1.69484833e-01, ...,
#         1.64555458e-01, 1.44546223e-04, 5.24022039e-02],
#        [1.79037947e-01, 1.77499830e-01, 1.72202932e-01, ...,
#         1.73287035e-01, 4.21023633e-02, 6.15548129e-01],
#        ...,
#        [9.67872348e-01, 9.72188506e-01, 9.68558428e-01, ...,
#         9.68285085e-01, 1.17172152e-01, 7.39517990e-01],
#        [9.64946865e-01, 9.70656909e-01, 9.69111663e-01, ...,
#         9.68518531e-01, 5.37556717e-02, 6.45093876e-01],
#        [9.68069262e-01, 9.70686233e-01, 9.69573079e-01, ...,
#         9.68397567e-01, 4.70150197e-02, 6.28887993e-01]])

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_train.shape, y_train.shape
# Out:
# ((1347, 60, 12), (1347,))

# %%
l = [1,2,3,4]

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1], 12)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
regressor.add(Dropout(0.4))

regressor.add(LSTM(units = 120, activation = 'relu'))
regressor.add(Dropout(0.5))

regressor.add(Dense(units = 1))

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            12600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 60)            26640
#
#  dropout_1 (Dropout)         (None, 60, 60)            0
#
#  lstm_2 (LSTM)               (None, 60, 80)            45120
#
#  dropout_2 (Dropout)         (None, 60, 80)            0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 180961 (706.88 KB)
# Trainable params: 180961 (706.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs=50, batch_size = 64)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 9s 159ms/step - loss: 0.0881
# Epoch 2/50
# 22/22 [==============================] - 3s 155ms/step - loss: 0.0170
# Epoch 3/50
# 22/22 [==============================] - 4s 203ms/step - loss: 0.0105
# Epoch 4/50
# 22/22 [==============================] - 3s 152ms/step - loss: 0.0090
# Epoch 5/50
# 22/22 [==============================] - 4s 169ms/step - loss: 0.0083
# Epoch 6/50
# 22/22 [==============================] - 5s 225ms/step - loss: 0.0073
# Epoch 7/50
# 22/22 [==============================] - 4s 169ms/step - loss: 0.0077
# Epoch 8/50
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0068
# Epoch 9/50
# 22/22 [==============================] - 5s 222ms/step - loss: 0.0071
# Epoch 10/50
# 22/22 [==============================] - 4s 171ms/step - loss: 0.0072
# Epoch 11/50
# 22/22 [==============================] - 4s 171ms/step - loss: 0.0064
# Epoch 12/50
# 22/22 [==============================] - 5s 213ms/step - loss: 0.0062
# Epoch 13/50
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0056
# Epoch 14/50
# 22/22 [==============================] - 4s 174ms/step - loss: 0.0057
# Epoch 15/50
# 22/22 [==============================] - 5s 239ms/step - loss: 0.0102
# Epoch 16/50
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0055
# Epoch 17/50
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0066
# Epoch 18/50
# 22/22 [==============================] - 5s 230ms/step - loss: 0.0049
# Epoch 19/50
# 22/22 [==============================] - 5s 225ms/step - loss: 0.0055
# Epoch 20/50
# 22/22 [==============================] - 5s 230ms/step - loss: 0.0053
# Epoch 21/50
# 22/22 [==============================] - 5s 241ms/step - loss: 0.0054
# Epoch 22/50
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0056
# Epoch 23/50
# 22/22 [==============================] - 6s 267ms/step - loss: 0.0053
# Epoch 24/50
# 22/22 [==============================] - 4s 175ms/step - loss: 0.0046
# Epoch 25/50
# 22/22 [==============================] - 4s 194ms/step - loss: 0.0049
# Epoch 26/50
# 22/22 [==============================] - 5s 199ms/step - loss: 0.0051
# Epoch 27/50
# 22/22 [==============================] - 4s 161ms/step - loss: 0.0044
# Epoch 28/50
# 22/22 [==============================] - 4s 176ms/step - loss: 0.0046
# Epoch 29/50
# 22/22 [==============================] - 5s 210ms/step - loss: 0.0049
# Epoch 30/50
# 22/22 [==============================] - 4s 161ms/step - loss: 0.0051
# Epoch 31/50
# 22/22 [==============================] - 4s 175ms/step - loss: 0.0042
# 827  1001.068551  52777.058480  1344.532489  54095.700580  48717.570626
# 828   940.757163  52542.886681  1269.926250  54095.721547  49016.016548
#
#         momentum  log_momentum
# 0     151.998047      5.023868
# 1     145.398438      4.979478
# 2     429.693359      6.063072
# 3      81.550781      4.401226
# 4     235.197266      5.460425
# ..           ...           ...
# 824  1727.203125      7.454259
# 825  1691.199219      7.433193
# 826  1320.449219      7.185727
# 827   998.902344      6.906657
# 828   721.851562      6.581820
#
# [829 rows x 12 columns]

# %%
inputs = scalar.fit_transform(dt)
print(inputs.shape)
inputs
# Out:
# (829, 12)
# array([[0.26586704, 0.28514032, 0.27373002, ..., 0.36710471, 0.02736787,
#         0.63431025],
#        [0.2729445 , 0.28814621, 0.27803495, ..., 0.37767074, 0.02617726,
#         0.62979669],
#        [0.27161095, 0.28854187, 0.27889362, ..., 0.37868236, 0.0774659 ,
#         0.73997631],
#        ...,
#        [1.        , 1.        , 0.99018617, ..., 0.98294892, 0.238164  ,
#         0.85412768],
#        [0.98702048, 0.99912978, 0.99543662, ..., 0.99139896, 0.18015487,
#         0.82575188],
#        [0.98015373, 0.99753344, 1.        , ..., 1.        , 0.13017312,
#         0.79272247]])

# %%
X_test = []
y_test = []

for i in range(60, inputs.shape[0]):
    X_test.append(inputs[i-60:i])
    y_test.append(inputs[i, 0])

X_test, y_test = np.array(X_test), np.array(y_test)
X_test.shape, y_test.shape
# Out:
# ((769, 60, 12), (769,))

# %%
y_pred = regressor.predict(X_test)
# Out:
# 25/25 [==============================] - 2s 45ms/step

# %%
y_pred
# Out:
# array([[0.24673942],
#        [0.24778964],
#        [0.24859759],
#        [0.24917066],
#        [0.24960254],
#        [0.24995239],
#        [0.25020212],
#        [0.2503318 ],
#        [0.25043997],
#        [0.25062203],
#        [0.25092274],
#        [0.25134322],
#        [0.2519306 ],
#        [0.25275576],
#        [0.25397044],
#        [0.2557093 ],
#        [0.25817207],
#        [0.2614873 ],
#        [0.2656443 ],
#        [0.27051443],
#        [0.2758481 ],
#        [0.28131384],
#        [0.28673697],
#        [0.2919799 ],
#        [0.296964  ],
#        [0.30163342],
#        [0.30589646],
#        [0.30961382],
#        [0.3126238 ],
#        [0.31485105],
#        [0.31631806],
#        [0.31721836],
#        [0.31761563],
#        [0.3175807 ],
#        [0.31713784],
#        [0.31641692],
#        [0.31561565],
#        [0.31489187],
#        [0.31445694],
#        [0.3144261 ],
#        [0.31494308],
#        [0.31622487],
#        [0.3183836 ],
#        [0.32140562],
#        [0.32520497],
#        [0.3295626 ],
#        [0.33412427],
#        [0.33861494],
#        [0.34266284],
#        [0.34602547],
#        [0.34837794],
#        [0.34963977],
#        [0.3499557 ],
#        [0.34965503],
#        [0.34903914],
#        [0.3483522 ],
#        [0.347719  ],
#        [0.34722894],
#        [0.3467705 ],
#        [0.3458712 ],
#        [0.3441031 ],
#        [0.34111825],
#        [0.33682704],
#        [0.33146667],
#        [0.32547808],
#        [0.31921375],
#        [0.31328464],
#        [0.3085183 ],
#        [0.3053089 ],
#        [0.30358982],
#        [0.30316538],
#        [0.30378634],
#        [0.14751536],
#        [0.149416  ],
#        [0.15090269],
#        [0.15201086],
#        [0.15267064],
#        [0.15297239],
#        [0.15291372],
#        [0.15260613],
#        [0.15233155],
#        [0.15238202],
#        [0.15306824],
#        [0.15455961],
#        [0.15724082],
#        [0.16128379],
#        [0.16696224],
#        [0.17426515],
#        [0.1832918 ],
#        [0.19372813],
#        [0.20519596],
#        [0.21707289],
#        [0.22878173],
#        [0.23983335],
#        [0.24989901],
#        [0.25853503],
#        [0.2653666 ],
#        [0.27035224],
#        [0.27374202],
#        [0.2755847 ],
#        [0.27637056],
#        [0.27665302],
#        [0.2768646 ],
#        [0.27731335],
#        [0.27824047],
#        [0.27981114],
#        [0.2820878 ],
#        [0.28493696],
#        [0.288188  ],
#        [0.2917685 ],
#        [0.29550353],
#        [0.2991389 ],
#        [0.3025517 ],
#        [0.30570388],
#        [0.30860072],
#        [0.3112465 ],
#        [0.31375837],
#        [0.31644127],
#        [0.31952828],
#        [0.32312053],
#        [0.3271371 ],
#        [0.3314637 ],
#        [0.3359561 ],
#        [0.3404676 ],
#        [0.3448701 ],
#        [0.34897903],
#        [0.35265714],
#        [0.3558852 ],
#        [0.35859627],
#        [0.36073065],
#        [0.3626594 ],
#        [0.36477533],
#        [0.36740243],
#        [0.37073046],
#        [0.374951  ],
#        [0.38022172],
#        [0.3866311 ],
#        [0.39408463],
#        [0.40247935],
#        [0.4115885 ],
#        [0.42099863],
#        [0.43031335],
#        [0.43913054],
#        [0.44710964],
#        [0.45407498],
#        [0.4599626 ],
#        [0.4645086 ],
#        [0.4678737 ],
#        [0.47023803],
#        [0.47106797],
#        [0.47060782],
#        [0.46910018],
#        [0.46653175],
#        [0.4627878 ],
#        [0.45805365],
#        [0.45279562],
#        [0.44730395],
#        [0.4418518 ],
#        [0.43657142],
#        [0.43136537],
#        [0.4263137 ],
#        [0.42175806],
#        [0.4179924 ],
#        [0.41497588],
#        [0.4128853 ],
#        [0.41181535],
#        [0.41168004],
#        [0.41238165],
#        [0.4138704 ],
#        [0.41612363],
#        [0.41903043],
#        [0.4223985 ],
#        [0.4260682 ],
#        [0.42996007],
#        [0.43387997],
#        [0.43764693],
#        [0.44109553],
#        [0.44402784],
#        [0.44635487],
#        [0.44811755],
#        [0.449448  ],
#        [0.45041257],
#        [0.4511516 ],
#        [0.45184237],
#        [0.45273405],
#        [0.45399278],
#        [0.45560902],
#        [0.457524  ],
#        [0.4596753 ],
#        [0.4620183 ],
#        [0.4644757 ],
#        [0.46686   ],
#        [0.46914536],
#        [0.47129983],
#        [0.47327435],
#        [0.47507435],
#        [0.47673446],
#        [0.47828448],
#        [0.4797455 ],
#        [0.4811594 ],
#        [0.48254228],
#        [0.48385835],
#        [0.48505127],
#        [0.48611087],
#        [0.48709762],
#        [0.48813033],
#        [0.48931587],
#        [0.49070382],
#        [0.49225742],
#        [0.49394196],
#        [0.49570614],
#        [0.49748576],
#        [0.4992147 ],
#        [0.5008453 ],
#        [0.5023975 ],
#        [0.50390047],
#        [0.5053581 ],
#        [0.50678074],
#        [0.5081651 ],
#        [0.5095502 ],
#        [0.51098603],
#        [0.51255566],
#        [0.5142983 ],
#        [0.51619345],
#        [0.51816994],
#        [0.52016443],
#        [0.5221247 ],
#        [0.52401465],
#        [0.52585804],
#        [0.5277168 ],
#        [0.52971745],
#        [0.5319779 ],
#        [0.5345226 ],
#        [0.53731984],
#        [0.5403571 ],
#        [0.5436147 ],
#        [0.547115  ],
#        [0.55084896],
#        [0.55473167],
#        [0.5585699 ],
#        [0.5621862 ],
#        [0.5654652 ],
#        [0.56794107],
#        [0.56911373],
#        [0.5687819 ],
#        [0.56683165],
#        [0.5633573 ],
#        [0.558762  ],
#        [0.5535316 ],
#        [0.54823846],
#        [0.5433175 ],
#        [0.53910816],
#        [0.5357889 ],
#        [0.53340656],
#        [0.5319852 ],
#        [0.5314722 ],
#        [0.5317304 ],
#        [0.5325143 ],
#        [0.53357303],
#        [0.5345929 ],
#        [0.5352626 ],
#        [0.53548825],
#        [0.5356091 ],
#        [0.5358736 ],
#        [0.536388  ],
#        [0.5371547 ],
#        [0.5381811 ],
#        [0.53944397],
#        [0.5409188 ],
#        [0.54255664],
#        [0.54351205],
#        [0.5431707 ],
#        [0.5413138 ],
#        [0.5383809 ],
#        [0.5348602 ],
#        [0.5309435 ],
#        [0.52659476],
#        [0.5218714 ],
#        [0.5167502 ],
#        [0.5114749 ],
#        [0.50618184],
#        [0.50105286],
#        [0.49666542],
#        [0.49335515],
#        [0.49126053],
#        [0.49040312],
#        [0.4907012 ],
#        [0.49199837],
#        [0.49410665],
#        [0.4967773 ],
#        [0.49971628],
#        [0.5024199 ],
#        [0.50461686],
#        [0.506203  ],
#        [0.50700337],
#        [0.50704545],
#        [0.5065895 ],
#        [0.50569093],
#        [0.50438046],
#        [0.50260556],
#        [0.50031424],
#        [0.49713796],
#        [0.49279732],
#        [0.48725635],
#        [0.4807495 ],
#        [0.47376263],
#        [0.46660167],
#        [0.45977587],
#        [0.45381224],
#        [0.44902235],
#        [0.44551945],
#        [0.44325924],
#        [0.44209492],
#        [0.4418081 ],
#        [0.44216663],
#        [0.4430036 ],
#        [0.44423813],
#        [0.4458112 ],
#        [0.4476617 ],
#        [0.4497764 ],
#        [0.45213103],
#        [0.45469075],
#        [0.4574679 ],
#        [0.4605379 ],
#        [0.4639625 ],
#        [0.46776277],
#        [0.4719119 ],
#        [0.47633666],
#        [0.48091823],
#        [0.48552287],
#        [0.490075  ],
#        [0.49454755],
#        [0.49895155],
#        [0.50328207],
#        [0.5075538 ],
#        [0.5117794 ],
#        [0.51598024],
#        [0.52012235],
#        [0.5241253 ],
#        [0.52792805],
#        [0.5315033 ],
#        [0.5348448 ],
#        [0.5379556 ],
#        [0.54084927],
#        [0.5435937 ],
#        [0.5463132 ],
#        [0.54905283],
#        [0.55187047],
#        [0.5548271 ],
#        [0.55796415],
#        [0.5613312 ],
#        [0.5648963 ],
#        [0.5685997 ],
#        [0.57233447],
#        [0.57598865],
#        [0.579511  ],
#        [0.58287   ],
#        [0.58599806],
#        [0.5885796 ],
#        [0.59020394],
#        [0.5905737 ],
#        [0.58979535],
#        [0.5880852 ],
#        [0.5859518 ],
#        [0.5836948 ],
#        [0.581486  ],
#        [0.57961386],
#        [0.5782975 ],
#        [0.5776156 ],
#        [0.57755244],
#        [0.57805395],
#        [0.5790338 ],
#        [0.58038056],
#        [0.58197075],
#        [0.5837174 ],
#        [0.5855711 ],
#        [0.5874918 ],
#        [0.5894478 ],
#        [0.5914274 ],
#        [0.59344834],
#        [0.5955462 ],
#        [0.5977702 ],
#        [0.6001859 ],
#        [0.6028284 ],
#        [0.6056879 ],
#        [0.6087276 ],
#        [0.6118792 ],
#        [0.61509603],
#        [0.6183754 ],
#        [0.62168205],
#        [0.62499666],
#        [0.62828606],
#        [0.63152486],
#        [0.6347015 ],
#        [0.63780093],
#        [0.6408308 ],
#        [0.6437878 ],
#        [0.6466612 ],
#        [0.6494635 ],
#        [0.6522197 ],
#        [0.6549545 ],
#        [0.65769273],
#        [0.6604445 ],
#        [0.6631873 ],
#        [0.66589725],
#        [0.6685608 ],
#        [0.67116135],
#        [0.6736848 ],
#        [0.67603666],
#        [0.67810625],
#        [0.6798336 ],
#        [0.6812201 ],
#        [0.68206245],
#        [0.68211496],
#        [0.68126136],
#        [0.6795458 ],
#        [0.677063  ],
#        [0.67382306],
#        [0.66998744],
#        [0.66582507],
#        [0.6616363 ],
#        [0.65750957],
#        [0.65319437],
#        [0.64858425],
#        [0.6438077 ],
#        [0.63901234],
#        [0.6344298 ],
#        [0.63017946],
#        [0.62630844],
#        [0.6229131 ],
#        [0.620059  ],
#        [0.61779505],
#        [0.6161324 ],
#        [0.61502963],
#        [0.6143896 ],
#        [0.6141259 ],
#        [0.614153  ],
#        [0.6144331 ],
#        [0.6149513 ],
#        [0.6156773 ],
#        [0.61659074],
#        [0.617673  ],
#        [0.61892664],
#        [0.6203658 ],
#        [0.6220349 ],
#        [0.6239024 ],
#        [0.6259841 ],
#        [0.62824935],
#        [0.63067144],
#        [0.63322383],
#        [0.6358917 ],
#        [0.6386644 ],
#        [0.6415309 ],
#        [0.644481  ],
#        [0.6475183 ],
#        [0.6506717 ],
#        [0.6539138 ],
#        [0.6572183 ],
#        [0.66054326],
#        [0.6638502 ],
#        [0.6671142 ],
#        [0.67032486],
#        [0.67347986],
#        [0.6765657 ],
#        [0.679578  ],
#        [0.6825045 ],
#        [0.6853305 ],
#        [0.6880514 ],
#        [0.69064885],
#        [0.69320315],
#        [0.695721  ],
#        [0.6981568 ],
#        [0.70048815],
#        [0.7026883 ],
#        [0.70475715],
#        [0.70668286],
#        [0.7084601 ],
#        [0.7100721 ],
#        [0.7115137 ],
#        [0.7127736 ],
#        [0.71383077],
#        [0.7146843 ],
#        [0.7153563 ],
#        [0.7158882 ],
#        [0.71633244],
#        [0.71674114],
#        [0.71717125],
#        [0.7176755 ],
#        [0.71827734],
#        [0.71898293],
#        [0.71980506],
#        [0.7207255 ],
#        [0.72171164],
#        [0.7227319 ],
#        [0.72377163],
#        [0.7247499 ],
#        [0.72559106],
#        [0.726247  ],
#        [0.7266681 ],
#        [0.7269166 ],
#        [0.72702473],
#        [0.72701806],
#        [0.7269225 ],
#        [0.7267823 ],
#        [0.7266403 ],
#        [0.72652733],
#        [0.7264797 ],
#        [0.7265088 ],
#        [0.7265927 ],
#        [0.7266976 ],
#        [0.72678906],
#        [0.72683495],
#        [0.7268204 ],
#        [0.72666734],
#        [0.72617334],
#        [0.7251772 ],
#        [0.72370017],
#        [0.7217917 ],
#        [0.71955997],
#        [0.71717227],
#        [0.71475136],
#        [0.71238005],
#        [0.7101335 ],
#        [0.70806986],
#        [0.70622474],
#        [0.70463437],
#        [0.7033927 ],
#        [0.70250934],
#        [0.70197827],
#        [0.7018328 ],
#        [0.70205986],
#        [0.7025826 ],
#        [0.70331424],
#        [0.70417565],
#        [0.7051088 ],
#        [0.7061068 ],
#        [0.7071479 ],
#        [0.70829815],
#        [0.70963115],
#        [0.71104133],
#        [0.712419  ],
#        [0.7136708 ],
#        [0.71481484],
#        [0.71581036],
#        [0.7166849 ],
#        [0.7176257 ],
#        [0.7188164 ],
#        [0.72028357],
#        [0.7219943 ],
#        [0.7239565 ],
#        [0.72614086],
#        [0.7281213 ],
#        [0.7295275 ],
#        [0.7301016 ],
#        [0.7297952 ],
#        [0.72889346],
#        [0.7278468 ],
#        [0.7271248 ],
#        [0.7269915 ],
#        [0.72746533],
#        [0.72844636],
#        [0.7297804 ],
#        [0.731353  ],
#        [0.733049  ],
#        [0.734787  ],
#        [0.73654157],
#        [0.73829347],
#        [0.74001276],
#        [0.7416989 ],
#        [0.743344  ],
#        [0.74493176],
#        [0.74646527],
#        [0.7479417 ],
#        [0.749374  ],
#        [0.75076205],
#        [0.75209993],
#        [0.7534042 ],
#        [0.75469357],
#        [0.75598764],
#        [0.7573252 ],
#        [0.75874645],
#        [0.76026213],
#        [0.7618598 ],
#        [0.7635098 ],
#        [0.7651384 ],
#        [0.7666664 ],
#        [0.7680829 ],
#        [0.76944417],
#        [0.7708147 ],
#        [0.77224714],
#        [0.7737517 ],
#        [0.77529263],
#        [0.77684265],
#        [0.77837497],
#        [0.7798894 ],
#        [0.7813948 ],
#        [0.7828829 ],
#        [0.7843221 ],
#        [0.785705  ],
#        [0.78703356],
#        [0.7883682 ],
#        [0.78961325],
#        [0.79070157],
#        [0.7916169 ],
#        [0.79237205],
#        [0.79300946],
#        [0.7935907 ],
#        [0.79415774],
#        [0.79475397],
#        [0.7955093 ],
#        [0.79639703],
#        [0.79739136],
#        [0.7984589 ],
#        [0.79963917],
#        [0.80098027],
#        [0.80248123],
#        [0.8041079 ],
#        [0.8058372 ],
#        [0.8076054 ],
#        [0.80937654],
#        [0.8111798 ],
#        [0.81303585]], dtype=float32)

# %%
scale = 1/scalar.scale_[0]  #Transforming the transformed data back to its original

# %%
y_pred = y_pred*scale
y_test = y_test*scale

# %%
plt.figure(figsize=(28,12))
plt.plot(y_test, color = 'red', label = 'Real Bank Nifty Price')
plt.plot(y_pred, color = 'blue', label = 'Predicted Bank Nifty Price')
plt.title('Bank Nifty Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
